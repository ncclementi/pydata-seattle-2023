# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib
from matplotlib import rcParams #install in the environment

# %%
# Add every font at the specified location - in this case Inter. 
font_dir = ["/Users/ncclementi/Documents/Inter/"]
for font in matplotlib.font_manager.findSystemFonts(font_dir):
    matplotlib.font_manager.fontManager.addfont(font)

# %%
rcParams['font.family'] = 'Inter'

# %%
df = pd.read_csv("memory_sampler_amm_demo_align.csv")

# %%
df
# Out:
#                             0        AMM on       AMM off
# 0             0 days 00:00:00  7.836201e+09  1.089206e+10
# 1      0 days 00:00:00.500320  7.837073e+09  1.089206e+10
# 2   0 days 00:00:00.500817152  7.837073e+09  1.089208e+10
# 3   0 days 00:00:01.000409088  7.837647e+09  1.089208e+10
# 4   0 days 00:00:01.000754944  7.837647e+09  1.089212e+10
# ..                        ...           ...           ...
# 91  0 days 00:00:23.000414976  8.661539e+10  9.781366e+10
# 92  0 days 00:00:23.000484096  8.661539e+10  6.476790e+10
# 93  0 days 00:00:23.500205056  6.262804e+10           NaN
# 94  0 days 00:00:24.000541952  4.745619e+10           NaN
# 95  0 days 00:00:24.500744960  3.131868e+10           NaN
#
# [96 rows x 3 columns]

# %%
df["total_sec"] = pd.to_timedelta(df["0"]).dt.total_seconds()

# %%
plt.plot(df["total_sec"], df["AMM on"]/ 2**30 , 
         '-', c="#1F5AFF", label='AMM on', lw=2.5)
plt.plot(df["total_sec"], df["AMM off"]/ 2**30 , 
         '-', c="#EF1561", label='AMM off', lw=2.5)
plt.ylabel("Cluster memory (GiB)", size=15)
plt.xlabel("Total seconds", size=15)
plt.legend(fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid()
plt.savefig("amm-ms-plot-array.svg", bbox_inches='tight');
